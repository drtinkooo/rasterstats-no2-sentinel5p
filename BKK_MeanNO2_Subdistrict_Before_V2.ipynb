# %%
import geopandas as gpd
import rasterio
from rasterio.plot import show
from rasterio.plot import show_hist
import rasterstats
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read the sub-districts of Bangkok Metropolis shapefile 
subdistricts = gpd.read_file(r'D:\Back up\BKK\BKK_V1.shp')

# %%
# Read the NO2 raster of before pandemic
no2 = rasterio.open(r'D:\Projects\Ajarn Noppol\005_COVID Project\COVID Thailand\Abstract\Version_2\Before_BKK_V2_Clip.tif', mode = 'r')

# %%
# Plotting the raster and the sub-districts shapefile together 
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (20,8))
show(no2, ax = ax1, title = 'NO2')
subdistricts.plot(ax = ax1, facecolor = 'None', edgecolor = 'red')
show_hist(no2, title = 'Histogram', ax = ax2)
plt.show()

# %%
# Assign raster values to a numpy nd array
nitrogendioxide_array = no2.read(1)

affine = no2.transform

# %%
# Calculating the zonal statistics 
avg_no2  = rasterstats.zonal_stats(subdistricts, nitrogendioxide_array, affine = affine,
                                      stats = ['mean'], 
                                      geojson_out = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\rasterstats\io.py:300: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")

# %%
# Extracting the average NO2 data from the list
avg_nitrogendioxide = []
i = 0

while i < len(avg_no2):
    avg_nitrogendioxide.append(avg_no2[i]['properties'])
    i = i + 1

# %%
# Transfering the infromation from the list to a pandas DataFrame

avg_no2_bkk_subdis_before = pd.DataFrame(avg_nitrogendioxide)
print(avg_no2_bkk_subdis_before)
# Out:
#       ADM0_EN ADM0_PCODE                      ADM0_TH  ADM1_EN ADM1_PCODE  \
# 0    Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# 1    Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# 2    Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# 3    Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# 4    Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# ..        ...        ...                          ...      ...        ...
# 164  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# 165  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# 166  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# 167  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
# 168  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Bangkok       TH10
#
#                                      ADM1_TH               ADM2_EN ADM2_PCODE  \
# 0    à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£             Bang Khen     TH1005
# 1    à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£           Bangkok Noi     TH1020
# 2    à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£  Pom Prap Sattru Phai     TH1008
# 3    à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£           Bangkok Noi     TH1020
# 4    à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£           Phra Nakhon     TH1001
# ..                                       ...                   ...        ...
# 164  à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£  Pom Prap Sattru Phai     TH1008
# 165  à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£           Bangkok Yai     TH1016
# 166  à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£  Pom Prap Sattru Phai     TH1008
# 167  à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£              Bang Sue     TH1029
# 168  à¸à¸£à¸¸à¸à¹à¸à¸à¸¡à¸«à¸²à¸à¸à¸£                Sathon     TH1028
#
#                                               ADM2_TH ADM3ALT1EN  ...  \
# 0                                  à¸à¸²à¸à¹à¸à¸       None  ...
# 1                      à¸à¸²à¸à¸à¸­à¸à¸à¹à¸­à¸¢       None  ...
# 2    à¸à¹à¸­à¸¡à¸à¸£à¸²à¸à¸¨à¸±à¸à¸£à¸¹à¸à¹à¸²       None  ...
# 3                      à¸à¸²à¸à¸à¸­à¸à¸à¹à¸­à¸¢       None  ...
# 4                                  à¸à¸£à¸°à¸à¸à¸£       None  ...
# ..                                                ...        ...  ...
# 164  à¸à¹à¸­à¸¡à¸à¸£à¸²à¸à¸¨à¸±à¸à¸£à¸¹à¸à¹à¸²       None  ...
# 165                    à¸à¸²à¸à¸à¸­à¸à¹à¸«à¸à¹       None  ...
# 166  à¸à¹à¸­à¸¡à¸à¸£à¸²à¸à¸¨à¸±à¸à¸£à¸¹à¸à¹à¸²       None  ...
# 167                             à¸à¸²à¸à¸à¸·à¹à¸­       None  ...
# 168                                      à¸ªà¸²à¸à¸£       None  ...
#
#            ADM3_EN ADM3_PCODE ADM3_REF  \
# 0        Anusawari   TH100502     None
# 1     Arun Ammarin   TH102009     None
# 2          Ban Bat   TH100804     None
# 3     Ban Chang Lo   TH102005     None
# 4    Ban Phan Thom   TH100110     None
# ..             ...        ...      ...
# 164   Wat Sommanat   TH100805     None
# 165   Wat Tha Phra   TH101602     None
# 166  Wat Thepsirin   TH100802     None
# 167    Wong Sawang   TH102902     None
# 168       Yan Nawa   TH102802     None
#
#                                         ADM3_TH Shape_Area Shape_Leng  \
# 0                à¸­à¸à¸¸à¸ªà¸²à¸§à¸£à¸µà¸¢à¹   0.001510   0.174592
# 1          à¸­à¸£à¸¸à¸à¸­à¸¡à¸£à¸´à¸à¸à¸£à¹   0.000253   0.079320
# 2                      à¸à¹à¸²à¸à¸à¸²à¸à¸£   0.000034   0.027559
# 3          à¸à¹à¸²à¸à¸à¹à¸²à¸à¸«à¸¥à¹à¸­   0.000193   0.062161
# 4                   à¸à¹à¸²à¸à¸à¸²à¸à¸à¸¡   0.000034   0.029040
# ..                                          ...        ...        ...
# 164                 à¸§à¸±à¸à¹à¸ªà¸¡à¸à¸±à¸ª   0.000038   0.028386
# 165                 à¸§à¸±à¸à¸à¹à¸²à¸à¸£à¸°   0.000453   0.084966
# 166  à¸§à¸±à¸à¹à¸à¸à¸¨à¸´à¸£à¸´à¸à¸à¸£à¹   0.000037   0.026103
# 167                 à¸§à¸à¸¨à¹à¸ªà¸§à¹à¸²à¸   0.000541   0.120705
# 168                       à¸¢à¸²à¸à¸à¸²à¸§à¸²   0.000205   0.067049
#
#            date     validOn  validTo      mean
# 0    2019-02-18  2019-02-21     None  0.000085
# 1    2019-02-18  2019-02-21     None  0.000163
# 2    2019-02-18  2019-02-21     None  0.000167
# 3    2019-02-18  2019-02-21     None  0.000172
# 4    2019-02-18  2019-02-21     None  0.000161
# ..          ...         ...      ...       ...
# 164  2019-02-18  2019-02-21     None  0.000158
# 165  2019-02-18  2019-02-21     None  0.000177
# 166  2019-02-18  2019-02-21     None  0.000164
# 167  2019-02-18  2019-02-21     None  0.000112
# 168  2019-02-18  2019-02-21     None  0.000159
#
# [169 rows x 23 columns]

# %%
avg_no2_bkk_subdis_before.to_csv('BKK_MeanNO2_Subdistrict_Before_V2.csv', encoding='utf-8')
