# %%
import geopandas as gpd
import rasterio
from rasterio.plot import show
from rasterio.plot import show_hist
import rasterstats
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read the sub-districts of Thailand shapefile 
subdistricts = gpd.read_file(r'D:\Thai\GIS Data\Humdata_Thailand administrative levels 0-3 boundaries\tha_adm_rtsd_itos_20190221_SHP_PART_2\tha_admbnda_adm3_rtsd_20190221.shp')

# %%
# Read the NO2 raster of during pandemic
no2 = rasterio.open(r'D:\Projects\Ajarn Noppol\005_COVID Project\COVID Thailand\Abstract\Version_2\During_Thai_V2_Clip.tif', mode = 'r')

# %%
# Plotting the raster and sub-districts of Thailand shapefile together 
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (20,8))
show(no2, ax = ax1, title = 'NO2')
subdistricts.plot(ax = ax1, facecolor = 'None', edgecolor = 'yellow')
show_hist(no2, title = 'Histogram', ax = ax2)
plt.show()

# %%
# Assign raster values to a numpy nd array
nitrogendioxide_array = no2.read(1)

affine = no2.transform

# %%
# Calculating the zonal statistics 
avg_no2  = rasterstats.zonal_stats(subdistricts, nitrogendioxide_array, affine = affine,
                                      stats = ['mean'], 
                                      geojson_out = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\rasterstats\io.py:300: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")

# %%
# Extracting the average NO2 data from the list
avg_nitrogendioxide = []
i = 0

while i < len(avg_no2):
    avg_nitrogendioxide.append(avg_no2[i]['properties'])
    i = i + 1

# %%
# Transfering the infromation from the list to a pandas DataFrame

avg_no2_thai_subdis_during = pd.DataFrame(avg_nitrogendioxide)
print(avg_no2_thai_subdis_during)
# Out:
#        ADM0_EN ADM0_PCODE                      ADM0_TH      ADM1_EN  \
# 0     Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢         Loei
# 1     Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢      Pattani
# 2     Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢        Surin
# 3     Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢         Yala
# 4     Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢          Nan
# ...        ...        ...                          ...          ...
# 7420  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢         Yala
# 7421  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢   Chiang Mai
# 7422  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢       Phayao
# 7423  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢   Chiang Mai
# 7424  Thailand         TH  à¸à¸£à¸°à¹à¸à¸¨à¹à¸à¸¢  Suphan Buri
#
#      ADM1_PCODE                         ADM1_TH         ADM2_EN ADM2_PCODE  \
# 0          TH42                       à¹à¸¥à¸¢          Tha Li     TH4208
# 1          TH94           à¸à¸±à¸à¸à¸²à¸à¸µ  Mueang Pattani     TH9401
# 2          TH32        à¸ªà¸¸à¸£à¸´à¸à¸à¸£à¹         Buachet     TH3213
# 3          TH95                    à¸¢à¸°à¸¥à¸²           Raman     TH9506
# 4          TH55                    à¸à¹à¸²à¸        Wiang Sa     TH5507
# ...         ...                             ...             ...        ...
# 7420       TH95                    à¸¢à¸°à¸¥à¸²     Mueang Yala     TH9501
# 7421       TH50     à¹à¸à¸µà¸¢à¸à¹à¸«à¸¡à¹     San Pa Tong     TH5012
# 7422       TH56                 à¸à¸°à¹à¸¢à¸²     Chiang Kham     TH5603
# 7423       TH50     à¹à¸à¸µà¸¢à¸à¹à¸«à¸¡à¹         Samoeng     TH5008
# 7424       TH72  à¸ªà¸¸à¸à¸£à¸£à¸à¸à¸¸à¸£à¸µ         U Thong     TH7209
#
#                                    ADM2_TH ADM3ALT1EN  ...      ADM3_EN  \
# 0                       à¸à¹à¸²à¸¥à¸µà¹       None  ...         A Hi
# 1     à¹à¸¡à¸·à¸­à¸à¸à¸±à¸à¸à¸²à¸à¸µ       None  ...       A Noru
# 2                       à¸à¸±à¸§à¹à¸à¸       None  ...       A Phon
# 3                          à¸£à¸²à¸¡à¸±à¸       None  ...       A Song
# 4                    à¹à¸§à¸µà¸¢à¸à¸ªà¸²       None  ...    Ai Na Lai
# ...                                    ...        ...  ...          ...
# 7420           à¹à¸¡à¸·à¸­à¸à¸¢à¸°à¸¥à¸²       None  ...        Yu Po
# 7421           à¸ªà¸±à¸à¸à¹à¸²à¸à¸­à¸       None  ...        Yu Wa
# 7422                 à¹à¸à¸µà¸¢à¸à¸à¸³       None  ...         Yuan
# 7423                    à¸ªà¸°à¹à¸¡à¸´à¸       None  ...    Yung Moen
# 7424                    à¸­à¸¹à¹à¸à¸­à¸       None  ...  Yung Thalai
#
#      ADM3_PCODE ADM3_REF                      ADM3_TH Shape_Area Shape_Leng  \
# 0      TH420803     None                 à¸­à¸²à¸®à¸µ   0.005078   0.360041
# 1      TH940102     None     à¸­à¸²à¹à¸à¸²à¸°à¸£à¸¹   0.000120   0.044900
# 2      TH321305     None              à¸­à¸²à¹à¸à¸   0.004086   0.365838
# 3      TH950615     None           à¸­à¸²à¸à¹à¸­à¸   0.003177   0.314589
# 4      TH550711     None  à¸­à¹à¸²à¸¢à¸à¸²à¹à¸¥à¸¢   0.014955   1.102764
# ...         ...      ...                          ...        ...        ...
# 7420   TH950103     None                 à¸¢à¸¸à¹à¸   0.002440   0.314057
# 7421   TH501201     None           à¸¢à¸¸à¸«à¸§à¹à¸²   0.001403   0.164018
# 7422   TH560301     None              à¸«à¸¢à¹à¸§à¸   0.001250   0.252568
# 7423   TH500805     None     à¸¢à¸±à¹à¸à¹à¸¡à¸´à¸   0.019629   0.779638
# 7424   TH720905     None  à¸¢à¸¸à¹à¸à¸à¸°à¸¥à¸²à¸¢   0.001861   0.321031
#
#             date     validOn  validTo      mean
# 0     2019-02-18  2019-02-21     None  0.000025
# 1     2019-02-18  2019-02-21     None  0.000011
# 2     2019-02-18  2019-02-21     None  0.000025
# 3     2019-02-18  2019-02-21     None  0.000010
# 4     2019-02-18  2019-02-21     None  0.000034
# ...          ...         ...      ...       ...
# 7420  2019-02-18  2019-02-21     None  0.000011
# 7421  2019-02-18  2019-02-21     None  0.000032
# 7422  2019-02-18  2019-02-21     None  0.000036
# 7423  2019-02-18  2019-02-21     None  0.000026
# 7424  2019-02-18  2019-02-21     None  0.000039
#
# [7425 rows x 23 columns]

# %%
avg_no2_thai_subdis_during.to_csv('Thai_MeanNO2_SubDis_During.csv', encoding='utf-8')
